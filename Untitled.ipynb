# %%
import pandas as pd

# %%
url="https://api.foursquare.com/v2/venues/search?client_id=0URO1O34DDEKYCW0LGTEM0FYCND1KJO2EUIFKDRSGDRW3ANX&client_secret=KWQZIUBNSY0M1TUCU3TBYFWDXEEZUVO5WUAKUIMXBGDSQLQP&v=20180602&ll=40.73,-74.01&query=coffee"

data=pd.read_json(url)

# %%
data
# Out:
#                                meta  \
# code                            200
# requestId  60110c2f148f584621e125f5
# venues                          NaN
#
#                                                     response
# code                                                     NaN
# requestId                                                NaN
# venues     [{'id': '546cb126498eabb0f206d61f', 'name': 'P...

# %%
data.loc["venues","response"]
# Out:
# [{'id': '546cb126498eabb0f206d61f',
#   'name': 'Partners Coffee Roasters',
#   'location': {'address': '44 Charles St',
#    'crossStreet': 'at 7th Ave S',
#    'lat': 40.73491348804492,
#    'lng': -74.00205073261284,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.73491348804492,
#      'lng': -74.00205073261284},
#     {'label': 'entrance', 'lat': 40.734954, 'lng': -74.002239}],
#    'distance': 865,
#    'postalCode': '10014',
#    'cc': 'US',
#    'neighborhood': 'West Village',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['44 Charles St (at 7th Ave S)',
#     'New York, NY 10014',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
# ...

# %%
pd.DataFrame(data.loc["venues","response"])
# Out:
#                           id                               name  \
# 0   546cb126498eabb0f206d61f           Partners Coffee Roasters
# 1   4aabd45bf964a5204d5a20e3          McNulty's Tea & Coffee Co
# 2   4a534cc4f964a5202cb21fe3                  Third Rail Coffee
# 3   512f8233e4b04458d4385195          Stumptown Coffee Roasters
# 4   55e9f118498eda28f897f9e3                 Kobrick Coffee Co.
# 5   4cd167456200b1f7d09fd928                        Coffee Cart
# 6   4eb92d8af790d87d04498393                       Coffee Wagon
# 7   4876216df964a52011511fe3            Jack's Stir Brew Coffee
# 8   56054685498e21a5e4c9d5b2            Coffee Project New York
# 9   49c406a8f964a5208d561fe3        Brooklyn Bagel & Coffee Co.
# 10  5b8e66ac234724002c927c4b    Brooklyn Bagel & Coffee Company
# 11  5df8e79880d839000816f937                 Joe Coffee Company
# 12  4f3a9e05bb3d2fbe725ca57a                 Blue Bottle Coffee
# 13  4ecc046b0e61aaf0384f19c4                       Think Coffee
# ...
